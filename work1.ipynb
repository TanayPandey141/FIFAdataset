# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("FIFA.csv")
pd.set_option('display.max_columns', None)
df.info

# %%
df.drop(['ID','Photo','Flag','Club Logo','Real Face','Jersey Number','Loaned From'],axis=1,inplace=True)

# %%
# df['International Reputation'].mean()
df['International Reputation'].fillna(1, inplace = True)
# df['Skill Moves'].median()
df['Skill Moves'].fillna(df['Skill Moves'].median(), inplace = True)
df['Weak Foot'].fillna(round(df['Weak Foot'].mean()), inplace = True)
df['Crossing'].fillna(round(df['Crossing'].mean()), inplace = True)
df['Finishing'].fillna(round(df['Finishing'].mean()), inplace = True)
df['HeadingAccuracy'].fillna(round(df['HeadingAccuracy'].mean()), inplace = True)
df['ShortPassing'].fillna(round(df['ShortPassing'].mean()), inplace = True)
df['Volleys'].fillna(round(df['Volleys'].mean()), inplace = True)
df['Dribbling'].fillna(round(df['Dribbling'].mean()), inplace = True)
df['Curve'].fillna(round(df['Curve'].mean()), inplace = True)
df['FKAccuracy'].fillna(round(df['FKAccuracy'].mean()), inplace = True)
df['LongPassing'].fillna(round(df['LongPassing'].mean()), inplace = True)
df['BallControl'].fillna(round(df['BallControl'].mean()), inplace = True)
df['Acceleration'].fillna(round(df['Acceleration'].mean()), inplace = True)
df['SprintSpeed'].fillna(round(df['SprintSpeed'].mean()), inplace = True)
df['Agility'].fillna(round(df['Agility'].mean()), inplace = True)
df['Reactions'].fillna(round(df['Reactions'].mean()), inplace = True)
df['Balance'].fillna(round(df['Balance'].mean()), inplace = True)
df['ShotPower'].fillna(round(df['ShotPower'].mean()), inplace = True)
df['Jumping'].fillna(round(df['Jumping'].mean()), inplace = True)
df['Stamina'].fillna(round(df['Stamina'].mean()), inplace = True)
df['Strength'].fillna(round(df['Strength'].mean()), inplace = True)
df['LongShots'].fillna(round(df['LongShots'].mean()), inplace = True)
df['Aggression'].fillna(round(df['Aggression'].mean()), inplace = True)
df['Interceptions'].fillna(round(df['Interceptions'].mean()), inplace = True)
df['Positioning'].fillna(round(df['Positioning'].mean()), inplace = True)
df['Vision'].fillna(round(df['Vision'].mean()), inplace = True)
df['Penalties'].fillna(round(df['Penalties'].mean()), inplace = True)
df['Composure'].fillna(round(df['Composure'].mean()), inplace = True)
df['Marking'].fillna(round(df['Marking'].mean()), inplace = True)
df['StandingTackle'].fillna(round(df['StandingTackle'].mean()), inplace = True)
df['SlidingTackle'].fillna(round(df['SlidingTackle'].mean()), inplace = True)

# %%
from google.colab import files
df.to_csv('new_data.csv', index=False)
files.download('new_data.csv')

# %%
df['GKDiving'].fillna(round(df['GKDiving'].mean()), inplace = True)
df['GKHandling'].fillna(round(df['GKHandling'].mean()), inplace = True)
df['GKKicking'].fillna(round(df['GKKicking'].mean()), inplace = True)
df['GKPositioning'].fillna(round(df['GKPositioning'].mean()), inplace = True)
df['GKReflexes'].fillna(round(df['GKReflexes'].mean()), inplace = True)

# %%
unnamed_columns = df.columns[df.columns.str.contains('^Unnamed')]
df = df.drop(unnamed_columns, axis=1)
df.shape
# Out:
# (18207, 81)

# %%
def value_and_wage_conversion(Value):
    if isinstance(Value,str):
        out = Value.replace('€', '')
        if 'M' in out:
            out = float(out.replace('M', ''))*1000000
        elif 'K' in Value:
            out = float(out.replace('K', ''))*1000
        return float(out)


df['Value'] = df['Value'].apply(lambda x: value_and_wage_conversion(x))
df['Wage'] = df['Wage'].apply(lambda x: value_and_wage_conversion(x))
df['Release Clause'] = df['Release Clause'].apply(lambda x: value_and_wage_conversion(x))
df['Release Clause'].fillna(df['Release Clause'].mean(), inplace = True)

# %%
df['Club'].fillna('No Club', inplace = True)

# %%
def clean_date(x):
    l=[]
    if isinstance(x,str):
        l=x.split(", ")
        x=l[-1]
    return(x)

df['Joined']=df['Joined'].replace(np.nan,0)
df['Joined'] = df['Joined'].apply(clean_date).astype('str')

# %%
def clean_weight(x):

    if isinstance(x,str):
        return(x.replace('lbs', ''))
    return(x)

df['Weight'] = df['Weight'].apply(clean_weight).astype('float')
df['Weight'].fillna(round(df['Weight'].mean()), inplace = True)

# %%
df['Work Rate'].value_counts()
df['Work Rate'].fillna('Medium/ Medium', inplace = True)

# %%
df['Preferred Foot'].value_counts()
df['Preferred Foot'].fillna('Right', inplace = True)

# %%
df['Body Type'].fillna('Normal', inplace = True)
df['Body Type'].value_counts()
df.info()

# %%
def skillConverter(val):
    if type(val) == str:
        s1 = val[0:2]
        s2 = val[-1]
        val = int(s1) + int(s2)
        return val
    else:
        return val

skill_columns = ['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM',
       'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM',
       'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']

for col in skill_columns:
    df[col] = df[col].apply(skillConverter)
    df[col].fillna(0.0, inplace = True)

# %%
df['Contract Valid Until'].fillna('Not available', inplace = True)
df.info()

# %%
fifa=df
def clean_height(x):
    l=[]
    s=1.0
    if isinstance(x,str):
        l=x.split("'")
        i=int(l[0])
        j=int(l[1])
        s=((i*12)+j)*2.54
    return(s)


fifa['Height'] = fifa['Height'].apply(clean_height)
fifa['Height'].fillna(round(fifa['Height'].mean()), inplace = True)

# %%
fifa['Body Type'][fifa['Body Type'] == 'Messi'] = 'Lean'
fifa['Body Type'][fifa['Body Type'] == 'C. Ronaldo'] = 'Normal'
fifa['Body Type'][fifa['Body Type'] == 'Neymar'] = 'Lean'
fifa['Body Type'][fifa['Body Type'] == 'Courtois'] = 'Lean'

fifa['Body Type'][fifa['Body Type'] == 'PLAYER_BODY_TYPE_25'] = 'Normal'
fifa['Body Type'][fifa['Body Type'] == 'Shaqiri'] = 'Stocky'
fifa['Body Type'][fifa['Body Type'] == 'Akinfenwa'] = 'Stocky'

# %%
df.dropna(subset=['Position'], inplace=True)
df.head()
# %matplotlib inline

# %%
player_features = ['Crossing', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
       'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping',
       'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions',
       'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking',
       'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']
df_postion  = pd.DataFrame()
for position_name, features in fifa.groupby(fifa['Position'])[player_features].mean().iterrows():
    top_features = dict(features.nlargest(5))
    df_postion[position_name] = tuple(top_features)
df_postion.head()

# %%
def right_footed(df):
    if (df['Preferred Foot'] == 'Right'):
        return 1
    else:
        return 0
fifa['Right_Foot'] = fifa.apply(right_footed, axis=1)
fifa.head()

# %%
tempwork = fifa["Work Rate"].str.split("/ ", n = 1, expand = True)
fifa["WorkRate1"]= tempwork[0]
fifa["WorkRate2"]= tempwork[1]
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value      Wage  Special Preferred Foot  \
# 0         FC Barcelona  110500000.0  565000.0     2202           Left
# 1             Juventus   77000000.0  405000.0     2228          Right
# 2  Paris Saint-Germain  118500000.0  290000.0     2143          Right
# 3    Manchester United   72000000.0  260000.0     1471          Right
# 4      Manchester City  102000000.0  355000.0     2281          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate Body Type  \
# 0                       5.0        4.0          4.0  Medium/ Medium      Lean
# ...

# %%
fifa.drop(['Name','Club','Wage','Preferred Foot','Work Rate','Joined',
          'Contract Valid Until','Release Clause'],axis=1,inplace=True)

# %%
ddf=df.copy(deep=True)

# %%
ddf["Body Type"]
body_type= {
    'Lean':0,
           'Normal':1,
           'Stocky':2
}
ddf['Body Type'] = ddf['Body Type'].map(body_type)

# %%
work_rate ={
    'Medium':1,
    'High':2,
    'Low':0
}
fif['WorkRate1'] = fif['WorkRate1'].map(work_rate)
fif['WorkRate2'] = fif['WorkRate2'].map(work_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-f58ffda24828> in <cell line: 6>()
#       4     'Low':0
#       5 }
# ----> 6 fif['WorkRate1'] = fif['WorkRate1'].map(work_rate)
#       7 fif['WorkRate2'] = fif['WorkRate2'].map(work_rate)
#
# NameError: name 'fif' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
fif['Height_Scaled'] = scaler.fit_transform(fif[['Height']]) * 99 + 1

# %%
fif['Weight_Scaled'] = scaler.fit_transform(fif[['Weight']]) * 99 + 1

# %%
inputs=fif.drop(['Nationality','Position','Height','Weight','Overall','Potential','Value'
                  ,],axis=1)
target=fif.Position

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_test,y_test)
# Out:
# 0.4402203856749311

# %%
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(fif[["Value"]], target, test_size=0.2)

rf = RandomForestClassifier(n_estimators=30)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=30)

# %%
rf.score(X_test,y_test)
# Out:
# 0.13911845730027547

# %%
fif.head()
# Out:
#    Age Nationality  Overall  Potential        Value  Special  \
# 0   31   Argentina       94         94  110500000.0     2202
# 1   33    Portugal       94         94   77000000.0     2228
# 2   26      Brazil       92         93  118500000.0     2143
# 3   27       Spain       91         93   72000000.0     1471
# 4   27     Belgium       91         92  102000000.0     2281
#
#    International Reputation  Weak Foot  Skill Moves  Body Type Position  \
# 0                       5.0        4.0          4.0          0       RF
# 1                       5.0        4.0          5.0          1       ST
# 2                       5.0        5.0          5.0          0       LW
# 3                       4.0        3.0          1.0          0       GK
# 4                       4.0        5.0          4.0          1      RCM
#
#    Height  Weight    LS    ST    RS    LW    LF    CF    RF    RW   LAM   CAM  \
# 0  170.18   159.0  90.0  90.0  90.0  94.0  95.0  95.0  95.0  94.0  95.0  95.0
# ...

# %%
fif.columns

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18147 entries, 0 to 18206
# Data columns (total 76 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       18147 non-null  int64
#  1   Nationality               18147 non-null  object
#  2   Overall                   18147 non-null  int64
#  3   Potential                 18147 non-null  int64
#  4   Value                     18147 non-null  float64
#  5   Special                   18147 non-null  int64
#  6   International Reputation  18147 non-null  float64
#  7   Weak Foot                 18147 non-null  float64
#  8   Skill Moves               18147 non-null  float64
#  9   Body Type                 18147 non-null  int64
#  10  Position                  18147 non-null  object
#  11  Height                    18147 non-null  float64
#  12  Weight                    18147 non-null  float64
# ...

# %%
df=pd.read_csv("FIFA_Processed_Data.csv")

unnamed_columns = [col for col in df.columns if col.startswith("Unnamed") or col == ""]
df = df.drop(unnamed_columns, axis=1)

# %%
df["Position"].dropna()
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
inputs=df.drop(['Position'],axis=1)

# %%
target=df.Position

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.2)

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier()

rfe = RFE(estimator=classifier, n_features_to_select=5)  # Select 5 features

rfe.fit(X, y)

selected_indices = rfe.get_support(indices=True)

selected_features = X.columns[selected_indices]
# Out:
# RandomForestClassifier(n_estimators=40)

# %%
model.score(X_test, y_test)
# Out:
# 0.22121212121212122
