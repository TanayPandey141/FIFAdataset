# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from pycaret.classification import *
data=pd.read_csv("myfifa.csv")
clf1 = setup(data, target='Position')
# Out:
# <style type="text/css">
# #T_6916d_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6916d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6916d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6916d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6916d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6916d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6916d_row0_col1" class="data row0 col1" >381</td>
#     </tr>
#     <tr>
#       <th id="T_6916d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6916d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6916d_row1_col1" class="data row1 col1" >Position</td>
#     </tr>
#     <tr>
#       <th id="T_6916d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(exclude=['gbc','lr','xgboost','lightgbm'],turbo=True)
# Out:
# <style type="text/css">
# #T_24289 th {
#   text-align: left;
# }
# ...

# %%
mymodel=create_model('rf')
# Out:
# <style type="text/css">
# #T_9c68c_row10_col0, #T_9c68c_row10_col1, #T_9c68c_row10_col2, #T_9c68c_row10_col3, #T_9c68c_row10_col4, #T_9c68c_row10_col5, #T_9c68c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9c68c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c68c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9c68c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9c68c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9c68c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9c68c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9c68c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9c68c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(mymodel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(mymodel, plot='feature')
